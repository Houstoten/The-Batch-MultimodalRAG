# %%
import requests
from bs4 import BeautifulSoup
import lxml
import html2text
from urllib.parse import urljoin, urlparse

from tqdm import tqdm

# %%
sitemap_url = 'https://www.deeplearning.ai/sitemap-0.xml'
scrap_url = 'https://www.deeplearning.ai/the-batch/'

# %%
def get_urls_from_sitemap(url) -> list:
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'xml')

    return [item.text for item in soup.find_all('loc') if item.text.startswith(scrap_url)]

links = get_urls_from_sitemap(sitemap_url)
len(links)
# Out:
# 4668

# %% [markdown]
# ## Now fetch into articles

# %%
def try_or_default(fn, default):
    try:
        return fn()
    except:
        return default

# %%
import re
import os
import pandas as pd

def download_file(url, folder):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            parsed_url = urlparse(url)
            filename = os.path.basename(parsed_url.path)

            if parsed_url.query:
                filename += re.sub(r"[^\w\-]", "_", parsed_url.query)

            if not filename or filename == "/":
                filename = "downloaded_image"

            if not re.match(r"^.*\.(jpg|jpeg|png|gif)$", filename):
                filename += '.jpg'

            filepath = os.path.join(folder, filename)
            os.makedirs(folder, exist_ok=True)

            with open(filepath, "wb") as f:
                f.write(response.content)

            # print(f"Downloaded {filename} from {url}")
    except Exception as e:
        # print(f"Failed to download {url}: {e}")
        return

def extract_and_download_images(soup: BeautifulSoup, base_url):
    images = soup.find_all("img", src=True)

    folder_path = os.path.join('article_images', base_url.replace(scrap_url, ''))

    for img_tag in images:
        img_url = urljoin(base_url, img_tag["src"])
        download_file(img_url, folder_path)


def extract_content_from_link(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    article = soup.select_one('article')

    title = try_or_default(lambda: article.select_one("h1.leading-tight").get_text(), '')

    publication_date = try_or_default(lambda: article.select_one('.container--boxed > div > div:first-child > div:last-child > div:first-child > div:last-child').get_text(), '')

    for data in article(['style', 'script', 'aside', 'footer', 'nav']) + soup.find_all("section", id="subscribe"):
        # Remove tags
        data.decompose()

    article_folder = os.path.join('articles', url.replace(scrap_url, ''))
    extract_and_download_images(article, url)

    for data in article(['header']):
        # Remove tags
        data.decompose()

    return title, publication_date, html2text.html2text(' '.join(soup.stripped_strings))


data = []
for link in tqdm(links[3:]):
    data.append((link, *extract_content_from_link(link)))
# Out:
#  30%|███       | 1402/4665 [40:56<1:35:17,  1.75s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 68
#      66 data = []
#      67 for link in tqdm(links[3:]):
# ---> 68     data.append((link, *extract_content_from_link(link)))
#
# Cell In[107], line 57, in extract_content_from_link(url)
#      54     data.decompose()
#      56 article_folder = os.path.join('articles', url.replace(scrap_url, ''))
# ---> 57 extract_and_download_images(article, url)
#      59 for data in article(['header']):
#      60     # Remove tags
#      61     data.decompose()
#
# Cell In[107], line 39, in extract_and_download_images(soup, base_url)
#      37 for img_tag in images:
#      38     img_url = urljoin(base_url, img_tag["src"])
# ---> 39     download_file(img_url, folder_path)
#
# Cell In[107], line 7, in download_file(url, folder)
#       5 def download_file(url, folder):
#       6     try:
# ----> 7         response = requests.get(url, stream=True)
#       8         if response.status_code == 200:
#       9             parsed_url = urlparse(url)
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/urllib3/connection.py:693, in HTTPSConnection.connect(self)
#     691 try:
#     692     sock: socket.socket | ssl.SSLSocket
# --> 693     self.sock = sock = self._new_conn()
#     694     server_hostname: str = self.host
#     695     tls_in_tls = False
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     194 """Establish a socket connection and set nodelay settings on it.
#     195
#     196 :return: New socket connection.
#     197 """
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#     206     raise NameResolutionError(self.host, self, e) from e
#
# File ~/miniconda3/envs/multimodal_rag/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
for link in tqdm(links[1403:]):
    data.append((link, *extract_content_from_link(link)))
# Out:
# 100%|██████████| 3265/3265 [1:42:03<00:00,  1.88s/it]

# %%
df = pd.DataFrame(data, columns =['Url', 'Title', 'Publication_Date', 'Content'])

# %%
df.set_index('Url', inplace=True)

# %%
df
# Out:
#                                                                                                 Title  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  Art team sells robot’s painting for $1.1 milli...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  SWE-Kit helps developers build their own assis...
# https://www.deeplearning.ai/the-batch/tensions-...  Robots On the Loading Dock Tensions mount as a...
# https://www.deeplearning.ai/the-batch/social-me...  Social Media Bots and the Amplification Effect...
# https://www.deeplearning.ai/the-batch/issue-274/
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/tag/weath...
# https://www.deeplearning.ai/the-batch/tag/webank/
# https://www.deeplearning.ai/the-batch/tag/weizm...
# https://www.deeplearning.ai/the-batch/tag/wells...
# https://www.deeplearning.ai/the-batch/tag/westl...
#
#                                                    Publication_Date  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...     Nov 11, 2024
# https://www.deeplearning.ai/the-batch/swe-kit-h...      Nov 8, 2024
# https://www.deeplearning.ai/the-batch/tensions-...     Nov 06, 2024
# https://www.deeplearning.ai/the-batch/social-me...     Nov 06, 2024
# https://www.deeplearning.ai/the-batch/issue-274/
# ...                                                             ...
# https://www.deeplearning.ai/the-batch/tag/weath...
# https://www.deeplearning.ai/the-batch/tag/webank/
# https://www.deeplearning.ai/the-batch/tag/weizm...
# https://www.deeplearning.ai/the-batch/tag/wells...
# https://www.deeplearning.ai/the-batch/tag/westl...
#
#                                                                                               Content
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  Data Points: Art team sells robot’s painting f...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  Data Points: SWE-Kit helps developers build th...
# https://www.deeplearning.ai/the-batch/tensions-...  Tensions Mount As Automation Transforms U.S. S...
# https://www.deeplearning.ai/the-batch/social-me...  Social Media Bots and the Amplification Effect...
# https://www.deeplearning.ai/the-batch/issue-274/    AI Controls Desktops, Agents Train Algorithms,...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/tag/weath...  Weather Predictions | The Batch Explore Course...
# https://www.deeplearning.ai/the-batch/tag/webank/   WeBank | The Batch | AI News & Insights Explor...
# https://www.deeplearning.ai/the-batch/tag/weizm...  Weizmann Institute | The Batch Explore Courses...
# https://www.deeplearning.ai/the-batch/tag/wells...  Wells Fargo | The Batch | AI News & Insights E...
# https://www.deeplearning.ai/the-batch/tag/westl...  Westlake University | The Batch Explore Course...
#
# [4667 rows x 3 columns]

# %%
deduped = df.drop_duplicates()

# %%
new_df = deduped[(deduped['Title'] != '')]

# %%
new_df
# Out:
#                                                                                                 Title  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  Art team sells robot’s painting for $1.1 milli...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  SWE-Kit helps developers build their own assis...
# https://www.deeplearning.ai/the-batch/tensions-...  Robots On the Loading Dock Tensions mount as a...
# https://www.deeplearning.ai/the-batch/social-me...  Social Media Bots and the Amplification Effect...
# https://www.deeplearning.ai/the-batch/openais-m...  When Agents Train Algorithms OpenAI’s MLE-benc...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/europe-ti...                         Europe Tightens the Screws
# https://www.deeplearning.ai/the-batch/vcs-bet-o...                                     VCs Bet on NLP
# https://www.deeplearning.ai/the-batch/drones-go...                               Drones Go Commercial
# https://www.deeplearning.ai/the-batch/automatic...                               Automatic Annotation
# https://www.deeplearning.ai/the-batch/the-robot...                             The Robots are Winning
#
#                                                    Publication_Date  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...     Nov 11, 2024
# https://www.deeplearning.ai/the-batch/swe-kit-h...      Nov 8, 2024
# https://www.deeplearning.ai/the-batch/tensions-...     Nov 06, 2024
# https://www.deeplearning.ai/the-batch/social-me...     Nov 06, 2024
# https://www.deeplearning.ai/the-batch/openais-m...     Nov 06, 2024
# ...                                                             ...
# https://www.deeplearning.ai/the-batch/europe-ti...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/vcs-bet-o...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/drones-go...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/automatic...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/the-robot...     Apr 17, 2019
#
#                                                                                               Content
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  Data Points: Art team sells robot’s painting f...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  Data Points: SWE-Kit helps developers build th...
# https://www.deeplearning.ai/the-batch/tensions-...  Tensions Mount As Automation Transforms U.S. S...
# https://www.deeplearning.ai/the-batch/social-me...  Social Media Bots and the Amplification Effect...
# https://www.deeplearning.ai/the-batch/openais-m...  OpenAI’s MLE-bench Tests AI Coding Agents Expl...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/europe-ti...  Europe Tightens the Screws | AI News & Insight...
# https://www.deeplearning.ai/the-batch/vcs-bet-o...  VCs Bet on NLP | AI News & Insights Explore Co...
# https://www.deeplearning.ai/the-batch/drones-go...  Drones Go Commercial | AI News & Insights Expl...
# https://www.deeplearning.ai/the-batch/automatic...  Automatic Annotation | AI News & Insights Expl...
# https://www.deeplearning.ai/the-batch/the-robot...  The Robots are Winning | AI News & Insights Ex...
#
# [1654 rows x 3 columns]

# %%
folders_clean = [url.replace('https://www.deeplearning.ai/the-batch/', '') for url in new_df.index]

# %%
import zipfile
import os
from tqdm import tqdm  # Ensure tqdm is used for the progress bar

def zip_selected_folders(output_filename, folder_list, base_directory='.'):
    with zipfile.ZipFile(output_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for folder_name in tqdm(folder_list):
            folder_path = os.path.join(base_directory, folder_name)
            if os.path.isdir(folder_path):
                for root, dirs, files in os.walk(folder_path):
                    for file in files:
                        file_path = os.path.join(root, file)
                        arcname = os.path.relpath(file_path, base_directory)
                        zipf.write(file_path, arcname)

# Usage
output_filename = 'images_clean.zip'
base_directory = 'article_images'  # Replace with your base directory path

zip_selected_folders(output_filename, folders_clean, base_directory)
# Out:
# 100%|██████████| 1654/1654 [01:19<00:00, 20.74it/s]

# %%
new_df.to_parquet('clean_df.parquet.gzip',
              compression='gzip')

# %%
new_df.to_csv('clean_df.csv')

# %%
from_csv_df = pd.read_csv('clean_df.csv')
from_csv_df
# Out:
#                                                     Url  \
# 0     https://www.deeplearning.ai/the-batch/art-team...
# 1     https://www.deeplearning.ai/the-batch/swe-kit-...
# 2     https://www.deeplearning.ai/the-batch/tensions...
# 3     https://www.deeplearning.ai/the-batch/social-m...
# 4     https://www.deeplearning.ai/the-batch/openais-...
# ...                                                 ...
# 1649  https://www.deeplearning.ai/the-batch/europe-t...
# 1650  https://www.deeplearning.ai/the-batch/vcs-bet-...
# 1651  https://www.deeplearning.ai/the-batch/drones-g...
# 1652  https://www.deeplearning.ai/the-batch/automati...
# 1653  https://www.deeplearning.ai/the-batch/the-robo...
#
#                                                   Title Publication_Date  \
# 0     Art team sells robot’s painting for $1.1 milli...     Nov 11, 2024
# 1     SWE-Kit helps developers build their own assis...      Nov 8, 2024
# 2     Robots On the Loading Dock Tensions mount as a...     Nov 06, 2024
# 3     Social Media Bots and the Amplification Effect...     Nov 06, 2024
# 4     When Agents Train Algorithms OpenAI’s MLE-benc...     Nov 06, 2024
# ...                                                 ...              ...
# 1649                         Europe Tightens the Screws     Apr 17, 2019
# 1650                                     VCs Bet on NLP     Apr 17, 2019
# 1651                               Drones Go Commercial     Apr 17, 2019
# 1652                               Automatic Annotation     Apr 17, 2019
# 1653                             The Robots are Winning     Apr 17, 2019
#
#                                                 Content
# 0     Data Points: Art team sells robot’s painting f...
# 1     Data Points: SWE-Kit helps developers build th...
# 2     Tensions Mount As Automation Transforms U.S. S...
# 3     Social Media Bots and the Amplification Effect...
# 4     OpenAI’s MLE-bench Tests AI Coding Agents Expl...
# ...                                                 ...
# 1649  Europe Tightens the Screws | AI News & Insight...
# 1650  VCs Bet on NLP | AI News & Insights Explore Co...
# 1651  Drones Go Commercial | AI News & Insights Expl...
# 1652  Automatic Annotation | AI News & Insights Expl...
# 1653  The Robots are Winning | AI News & Insights Ex...
#
# [1654 rows x 4 columns]

# %%
def extract_unformatted_content_from_link(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    article = soup.select_one('article')


    for data in article(['style', 'script', 'aside', 'footer', 'nav', 'header']) + soup.find_all("section", id="subscribe"):
        # Remove tags
        data.decompose()

    return article

new_content_list = []

# extract_unformatted_content_from_link(new_df.index[0])

# %%
for url in tqdm(new_df.index):
    new_content_list.append(extract_unformatted_content_from_link(url))
# Out:
# 100%|██████████| 1654/1654 [17:05<00:00,  1.61it/s]

# %%
new_df['Content_HTML'] = new_content_list
# Out:
# /var/folders/ms/y2cmr8tj7md785mb1f7vct100000gn/T/ipykernel_43269/806563990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Content_HTML'] = new_content_list

# %%
new_df
# Out:
#                                                                                                 Title  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  Art team sells robot’s painting for $1.1 milli...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  SWE-Kit helps developers build their own assis...
# https://www.deeplearning.ai/the-batch/tensions-...  Robots On the Loading Dock Tensions mount as a...
# https://www.deeplearning.ai/the-batch/social-me...  Social Media Bots and the Amplification Effect...
# https://www.deeplearning.ai/the-batch/openais-m...  When Agents Train Algorithms OpenAI’s MLE-benc...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/europe-ti...                         Europe Tightens the Screws
# https://www.deeplearning.ai/the-batch/vcs-bet-o...                                     VCs Bet on NLP
# https://www.deeplearning.ai/the-batch/drones-go...                               Drones Go Commercial
# https://www.deeplearning.ai/the-batch/automatic...                               Automatic Annotation
# https://www.deeplearning.ai/the-batch/the-robot...                             The Robots are Winning
#
#                                                    Publication_Date  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...     Nov 11, 2024
# https://www.deeplearning.ai/the-batch/swe-kit-h...      Nov 8, 2024
# https://www.deeplearning.ai/the-batch/tensions-...     Nov 06, 2024
# https://www.deeplearning.ai/the-batch/social-me...     Nov 06, 2024
# https://www.deeplearning.ai/the-batch/openais-m...     Nov 06, 2024
# ...                                                             ...
# https://www.deeplearning.ai/the-batch/europe-ti...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/vcs-bet-o...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/drones-go...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/automatic...     Apr 17, 2019
# https://www.deeplearning.ai/the-batch/the-robot...     Apr 17, 2019
#
#                                                                                               Content  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  Data Points: Art team sells robot’s painting f...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  Data Points: SWE-Kit helps developers build th...
# https://www.deeplearning.ai/the-batch/tensions-...  Tensions Mount As Automation Transforms U.S. S...
# https://www.deeplearning.ai/the-batch/social-me...  Social Media Bots and the Amplification Effect...
# https://www.deeplearning.ai/the-batch/openais-m...  OpenAI’s MLE-bench Tests AI Coding Agents Expl...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/europe-ti...  Europe Tightens the Screws | AI News & Insight...
# https://www.deeplearning.ai/the-batch/vcs-bet-o...  VCs Bet on NLP | AI News & Insights Explore Co...
# https://www.deeplearning.ai/the-batch/drones-go...  Drones Go Commercial | AI News & Insights Expl...
# https://www.deeplearning.ai/the-batch/automatic...  Automatic Annotation | AI News & Insights Expl...
# https://www.deeplearning.ai/the-batch/the-robot...  The Robots are Winning | AI News & Insights Ex...
#
#                                                                                          Content_HTML
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  [[[<p>Twice a week, Data Points brings you the...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  [[[<p>Twice a week, Data Points brings you the...
# https://www.deeplearning.ai/the-batch/tensions-...  [[[<p>Shipping ports are the latest front in t...
# https://www.deeplearning.ai/the-batch/social-me...  [[[<p>Dear friends,</p>, <p>Trump and the Repu...
# https://www.deeplearning.ai/the-batch/openais-m...  [[[<p>Coding agents are improving, but can the...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/europe-ti...  [[[<p>The European Commission pulled ahead of ...
# https://www.deeplearning.ai/the-batch/vcs-bet-o...  [[[<p>Two startups specializing in NLP reporte...
# https://www.deeplearning.ai/the-batch/drones-go...  [[[<p>Alphabet spin-out Wing <a href="https://...
# https://www.deeplearning.ai/the-batch/automatic...  [[[<p>A new tool promises to speed up the labo...
# https://www.deeplearning.ai/the-batch/the-robot...  [[[<p>Two prominent economists cast doubt on r...
#
# [1654 rows x 4 columns]

# %%
new_df[['Content', 'Content_HTML']]
# Out:
#                                                                                               Content  \
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  Data Points: Art team sells robot’s painting f...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  Data Points: SWE-Kit helps developers build th...
# https://www.deeplearning.ai/the-batch/tensions-...  Tensions Mount As Automation Transforms U.S. S...
# https://www.deeplearning.ai/the-batch/social-me...  Social Media Bots and the Amplification Effect...
# https://www.deeplearning.ai/the-batch/openais-m...  OpenAI’s MLE-bench Tests AI Coding Agents Expl...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/europe-ti...  Europe Tightens the Screws | AI News & Insight...
# https://www.deeplearning.ai/the-batch/vcs-bet-o...  VCs Bet on NLP | AI News & Insights Explore Co...
# https://www.deeplearning.ai/the-batch/drones-go...  Drones Go Commercial | AI News & Insights Expl...
# https://www.deeplearning.ai/the-batch/automatic...  Automatic Annotation | AI News & Insights Expl...
# https://www.deeplearning.ai/the-batch/the-robot...  The Robots are Winning | AI News & Insights Ex...
#
#                                                                                          Content_HTML
# Url
# https://www.deeplearning.ai/the-batch/art-team-...  [[[<p>Twice a week, Data Points brings you the...
# https://www.deeplearning.ai/the-batch/swe-kit-h...  [[[<p>Twice a week, Data Points brings you the...
# https://www.deeplearning.ai/the-batch/tensions-...  [[[<p>Shipping ports are the latest front in t...
# https://www.deeplearning.ai/the-batch/social-me...  [[[<p>Dear friends,</p>, <p>Trump and the Repu...
# https://www.deeplearning.ai/the-batch/openais-m...  [[[<p>Coding agents are improving, but can the...
# ...                                                                                               ...
# https://www.deeplearning.ai/the-batch/europe-ti...  [[[<p>The European Commission pulled ahead of ...
# https://www.deeplearning.ai/the-batch/vcs-bet-o...  [[[<p>Two startups specializing in NLP reporte...
# https://www.deeplearning.ai/the-batch/drones-go...  [[[<p>Alphabet spin-out Wing <a href="https://...
# https://www.deeplearning.ai/the-batch/automatic...  [[[<p>A new tool promises to speed up the labo...
# https://www.deeplearning.ai/the-batch/the-robot...  [[[<p>Two prominent economists cast doubt on r...
#
# [1654 rows x 2 columns]

# %%
new_df['Content'] = new_df['Content_HTML']
new_df.drop(['Content_HTML'], axis=1, inplace=True)

# %%
new_df.to_csv('articles_html.csv')

# %%
pd.read_csv('articles_html.csv')
# Out:
#                                                     Url  \
# 0     https://www.deeplearning.ai/the-batch/art-team...
# 1     https://www.deeplearning.ai/the-batch/swe-kit-...
# 2     https://www.deeplearning.ai/the-batch/tensions...
# 3     https://www.deeplearning.ai/the-batch/social-m...
# 4     https://www.deeplearning.ai/the-batch/openais-...
# ...                                                 ...
# 1649  https://www.deeplearning.ai/the-batch/europe-t...
# 1650  https://www.deeplearning.ai/the-batch/vcs-bet-...
# 1651  https://www.deeplearning.ai/the-batch/drones-g...
# 1652  https://www.deeplearning.ai/the-batch/automati...
# 1653  https://www.deeplearning.ai/the-batch/the-robo...
#
#                                                   Title Publication_Date  \
# 0     Art team sells robot’s painting for $1.1 milli...     Nov 11, 2024
# 1     SWE-Kit helps developers build their own assis...      Nov 8, 2024
# 2     Robots On the Loading Dock Tensions mount as a...     Nov 06, 2024
# 3     Social Media Bots and the Amplification Effect...     Nov 06, 2024
# 4     When Agents Train Algorithms OpenAI’s MLE-benc...     Nov 06, 2024
# ...                                                 ...              ...
# 1649                         Europe Tightens the Screws     Apr 17, 2019
# 1650                                     VCs Bet on NLP     Apr 17, 2019
# 1651                               Drones Go Commercial     Apr 17, 2019
# 1652                               Automatic Annotation     Apr 17, 2019
# 1653                             The Robots are Winning     Apr 17, 2019
#
#                                                 Content
# 0     <article class="pb-16 bg-white"><div class="po...
# 1     <article class="pb-16 bg-white"><div class="po...
# 2     <article class="pb-16 bg-white"><div class="po...
# 3     <article class="pb-16 bg-white"><div class="po...
# 4     <article class="pb-16 bg-white"><div class="po...
# ...                                                 ...
# 1649  <article class="pb-16 bg-white"><div class="po...
# 1650  <article class="pb-16 bg-white"><div class="po...
# 1651  <article class="pb-16 bg-white"><div class="po...
# 1652  <article class="pb-16 bg-white"><div class="po...
# 1653  <article class="pb-16 bg-white"><div class="po...
#
# [1654 rows x 4 columns]
